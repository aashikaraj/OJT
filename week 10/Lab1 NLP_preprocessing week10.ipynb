# %% [markdown]
# # NLP preprocessing unit

# %%
# !pip install snorkel spacy-nightly[transformers,cuda100] --pre

import spacy
import spacy_transformers

from spacy.cli import download
download("en_core_web_trf")

nlp = spacy.load("en_core_web_trf")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.0 MB 991.0 kB/s eta 0:00:07
#       --------------------------------------- 0.1/7.0 MB 1.7 MB/s eta 0:00:04
#      - -------------------------------------- 0.3/7.0 MB 2.2 MB/s eta 0:00:04
#      -- ------------------------------------- 0.5/7.0 MB 2.6 MB/s eta 0:00:03
#      --- ------------------------------------ 0.5/7.0 MB 2.8 MB/s eta 0:00:03
#      ----- ---------------------------------- 0.9/7.0 MB 3.7 MB/s eta 0:00:02
#      ------ --------------------------------- 1.0/7.0 MB 3.7 MB/s eta 0:00:02
#      ------ --------------------------------- 1.1/7.0 MB 3.1 MB/s eta 0:00:02
#      ------- -------------------------------- 1.3/7.0 MB 3.3 MB/s eta 0:00:02
#      --------- ------------------------------ 1.6/7.0 MB 3.5 MB/s eta 0:00:02
# ...

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.4/12.8 MB 11.9 MB/s eta 0:00:02
#      -- ------------------------------------- 0.7/12.8 MB 9.5 MB/s eta 0:00:02
#      --- ------------------------------------ 1.1/12.8 MB 8.4 MB/s eta 0:00:02
#      ---- ----------------------------------- 1.3/12.8 MB 7.6 MB/s eta 0:00:02
#      ----- ---------------------------------- 1.7/12.8 MB 7.8 MB/s eta 0:00:02
#      ------ --------------------------------- 2.2/12.8 MB 8.1 MB/s eta 0:00:02
#      -------- ------------------------------- 2.6/12.8 MB 8.2 MB/s eta 0:00:02
#      --------- ------------------------------ 3.0/12.8 MB 8.2 MB/s eta 0:00:02
#      ---------- ----------------------------- 3.4/12.8 MB 8.3 MB/s eta 0:00:02
#      ----------- ---------------------------- 3.8/12.8 MB 8.3 MB/s eta 0:00:02
# ...

# %%
# Sentence and Word tokenization using NLTK.
from nltk import download
download('punkt')

from nltk.tokenize import word_tokenize, sent_tokenize

text = "Natural Language Processing is fun. Let's learn more about it."

# Word Tokenization
word_tokens = word_tokenize(text)
print("Word Tokens:", word_tokens)

# Sentence Tokenization
sentence_tokens = sent_tokenize(text)
print("Sentence Tokens:", sentence_tokens)
# Out:
# Word Tokens: ['Natural', 'Language', 'Processing', 'is', 'fun', '.', 'Let', "'s", 'learn', 'more', 'about', 'it', '.']
# Sentence Tokens: ['Natural Language Processing is fun.', "Let's learn more about it."]
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\admi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# using Spacy
import spacy

# Load the English tokenizer, tagger, parser, NER, and word vectors
nlp = spacy.load('en_core_web_sm')

# Replace 'text' with your actual text to tokenize
text = "Replace this with your actual text."

# Process the text with SpaCy
doc = nlp(text)

# Word Tokenization
word_tokens = [token.text for token in doc]
print("Word Tokens:", word_tokens)

# Sentence Tokenization
sentence_tokens = [sent.text for sent in doc.sents]
print("Sentence Tokens:", sentence_tokens)
# Out:
# Word Tokens: ['Replace', 'this', 'with', 'your', 'actual', 'text', '.']
# Sentence Tokens: ['Replace this with your actual text.']

# %% [markdown]
# # Stemming using NLTK

# %%
from nltk.stem import PorterStemmer, SnowballStemmer

words = ["running", "runner", "runs", "happiness", "happily"]

# Porter = PortStemmer
porter = PorterStemmer()
porter_stems = [porter.stem(word) for word in words]
print("Porter Stemming:", porter_stems)

# Snowball Stemmer
snowball = SnowballStemmer(language='english')
snowball_stems = [snowball.stem(word) for word in words]
print("Snowball Stemming:", snowball_stems)
# Out:
# Porter Stemming: ['run', 'runner', 'run', 'happi', 'happili']
# Snowball Stemming: ['run', 'runner', 'run', 'happi', 'happili']

# %% [markdown]
# # Lemmatization using NLTK

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

download('wordnet')
download('omw-1.4')

lemmatizer = WordNetLemmatizer()
words = ["running", "runner", "runs", "hapiness", "happily", "better"]

# Lemmatizing with part-of-speech tagging
lemmas = [lemmatizer.lemmatize(word, pos=wordnet.VERB) for word in words]
print("Lemmatized (Verb):", lemmas)

lemmas = [lemmatizer.lemmatize(word, pos=wordnet.ADJ) for word in words]
print("Lemmatized (Adjective):", lemmas)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\admi\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\admi\AppData\Roaming\nltk_data...
# Lemmatized (Verb): ['run', 'runner', 'run', 'hapiness', 'happily', 'better']
# Lemmatized (Adjective): ['running', 'runner', 'runs', 'hapiness', 'happily', 'good']

# %% [markdown]
# # Lemmatization using spacy

# %%
doc = nlp("running runner runs hapiness happily better")

lemmas = [token.lemma_ for token in doc]
print("Lemmatized:", lemmas)
# Out:
# Lemmatized: ['run', 'runner', 'run', 'hapiness', 'happily', 'well']
